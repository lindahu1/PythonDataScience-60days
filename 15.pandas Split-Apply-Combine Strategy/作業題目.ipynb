# %% [markdown]
# 作業目標:<br>
# 1. 熟悉分組計算

# %% [markdown]
# 作業重點: <br>
# 1. 分組計算也可以加入apply自定義的函數

# %% [markdown]
# 題目 : 運用下列分數資料分析<br>
# 1. 找出全年級各科成績最高分與最低分?<br>
# 2. 找出數學班平均最高的班級?<br>
# 3. 分析全校女生與男生國文平均差幾分?<br>
# score_df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])

# %%
import pandas as pd
score_df = pd.DataFrame([[1,50,80,70,'boy',1], 
              [2,60,45,50,'boy',2],
              [3,98,43,55,'boy',1],
              [4,70,69,89,'boy',2],
              [5,56,79,60,'girl',1],
              [6,60,68,55,'girl',2],
              [7,45,70,77,'girl',1],
              [8,55,77,76,'girl',2],
              [9,25,57,60,'girl',1],
              [10,88,40,43,'girl',3],
              [11,25,60,45,'boy',3],
              [12,80,60,23,'boy',3],
              [13,20,90,66,'girl',3],
              [14,50,50,50,'girl',3],
              [15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])
score_df
# Out:
#     student_id  math_score  english_score  chinese_score   sex  class
# 0            1          50             80             70   boy      1
# 1            2          60             45             50   boy      2
# 2            3          98             43             55   boy      1
# 3            4          70             69             89   boy      2
# 4            5          56             79             60  girl      1
# 5            6          60             68             55  girl      2
# 6            7          45             70             77  girl      1
# 7            8          55             77             76  girl      2
# 8            9          25             57             60  girl      1
# 9           10          88             40             43  girl      3
# 10          11          25             60             45   boy      3
# 11          12          80             60             23   boy      3
# ...

# %%
#1.找出全年級各科成績最高分與最低分?
score_df.groupby(['class'])['chinese_score','english_score','math_score'].agg(['max','min'])
# Out:
#       chinese_score     english_score     math_score
#                 max min           max min        max min
# class
# 1                77  55            80  43         98  25
# 2                89  50            77  45         70  55
# 3                77  23            90  40         89  20

# %%
#2.找出數學班平均最高的班級?
score_df.groupby(['class'])['math_score'].mean().idxmax()
# Out:
# 2

# %%
#3.分析全校女生與男生國文平均差幾分?
score_df.loc[score_df.sex=='girl']['chinese_score'].mean() - score_df.loc[score_df.sex=='boy']['chinese_score'].mean()
# Out:
# 7.333333333333329
